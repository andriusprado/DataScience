# %% [markdown]
# # Aplicações com Seaborn
# Baseada no Matplotlib, o Seaborn é uma biblioteca que possui maior qualidade e diferenciação nos gráficos gerados em relação a biblioteca em que se baseia.

# %%
import seaborn as sns

# %%
    df_tips = sns.load_dataset("tips")

# %% [markdown]
# ## Relações estatísticas

# %% [markdown]
# ### Relplot

# %%
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", style="sex", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", style="smoker", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", size="size", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15,300), data=tips)

# %%
# %matplotlib inline
sns.scatterplot(x="total_bill", y="tip", hue="day", style="time", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
f, ax = plt.subplots(figsize=(15, 7))
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Paletas de cores

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Accent"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("PuOr"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Blues"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Reds"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("YlOrRd"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("PuBuGn"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("BrBG"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("RdBu"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Spectral"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("coolwarm"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Pastel2"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Accent"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Dark2"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("Set3"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("tab20"))

# %%
# %matplotlib inline
sns.palplot(sns.color_palette("tab20c"))

# %%
# %matplotlib inline
sns.relplot(x="total_bill", y="tip", hue="size", palette="Purples", size="size", sizes=(12,250), data=tips);

# %%
# %matplotlib inline
sns.catplot(x="sex", kind="count", palette="Set3", data=tips);

# %%
# %matplotlib inline
sns.heatmap(tips.corr(), annot=True, cmap="RdBu")
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
sns.set_palette("Pastel2")

# plot usando a paleta de cor "pastel"
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
# %matplotlib inline
# Plota o gráfico definindo uma opção de cor temporária
with sns.color_palette("Accent"):
  sns.relplot(x="total_bill", y="tip", size="size", sizes=(12,250), data=tips)

# %%
sns.catplot(y="day", kind="count", palette="Set2", data=tips)

# %%
sns.catplot(x="day", y="total_bill", palette="Set2", data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind='swarm', data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind='swarm', hue="sex", palette="Dark2", data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind='swarm', hue="sex", order=['Sat','Sun','Fri','Thur'], palette="Accent", data=tips)

# %%
sns.catplot(x="total_bill", y="day", kind="swarm", data=tips)

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
# %matplotlib inline
sns.lmplot(x="total_bill", y="tip", hue="sex", palette="Pastel1", data=tips)

# %%
# %matplotlib inline
sns.lmplot(x="total_bill",y="tip", hue="smoker", col="time", palette="Set2", data=tips)

# %%
# %matplotlib inline
sns.lmplot(x="total_bill",
           y="tip", 
           hue="smoker", 
           col="time", 
           palette="Set1",
           data=tips, 
           scatter_kws={'s': 90, 'alpha': 0.5},
           line_kws={'lw': 4});

# %%
# %matplotlib inline
sns.lmplot(x="total_bill", y="tip", hue="smoker",col="time", row="sex", palette="Set2", data=tips)

# %%
sns.catplot(x="day", y="total_bill", palette="Set1", kind="box", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="boxen", data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind="boxen", data=tips);
sns.stripplot(x="day", y="total_bill", data=tips, color="blue");

# %%
# %matplotlib inline
sns.catplot(x="sex", y="total_bill", hue="smoker", col="time", data=tips, kind="boxen",height=4)

# %%
sns.catplot(x="day", y="total_bill", kind="violin", data=tips)

# %%
sns.catplot(x="total_bill", y="day", kind="violin", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="time", kind="violin", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", split=True , kind="violin", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", split=True , inner="stick", palette="pastel", kind="violin", data=tips);

# %%
sns.catplot(x="day", y="total_bill", palette="pastel", kind="violin", data=tips);
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(tips.total_bill, kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
import numpy as np
x = np.random.normal(size=100)

# %%
sns.histplot(x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(tips.total_bill, bins=50, kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips.total_bill, hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips.total_bill, hist=True, rug=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.jointplot(x="tip", y="total_bill", color='r', data=tips)

# %%
sns.jointplot(x="tip", y="total_bill", color='r', kind="hex", data=tips)

# %%
sns.jointplot(x="tip", y="total_bill", color='b', kind="kde", data=tips)

# %%
sns.pairplot(tips)

# %%
iris = sns.load_dataset("iris")

# %%
sns.pairplot(iris, hue="species", palette="Set1")

# %%
sns.pairplot(iris, kind="reg")

# %%
sns.pairplot(iris,hue="species", diag_kind="hist")

# %%
sns.pairplot(iris, hue="species", vars=["sepal_width", "sepal_length"], palette="husl")

# %%
correlacoes = iris.corr()

# %%
ax = sns.heatmap(correlacoes)

# %%
ax = sns.heatmap(correlacoes, annot=True)

# %%
ax = sns.heatmap(correlacoes, cmap='PuOr', annot=True)
